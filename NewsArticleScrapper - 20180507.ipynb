# %%
import feedparser as fp
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import pandas as pd
import nltk as nlp
from nltk.tag.stanford import StanfordNERTagger as nert

# %%
# Set the limit for number of articles to download
LIMIT = 100

# %%
data = {}
data['newspapers'] = {}
news = pd.DataFrame([],columns=['Title','Text','Link','Published','Type'])

# %%
# Loads the JSON files with news sites
with open('NewsPapers.json') as data_file:
    companies = json.load(data_file)

# %%
companies
# Out:
# {'bbc': {'link': 'http://www.bbc.com/',
#   'rss': 'http://feeds.bbci.co.uk/news/rss.xml'},
#  'cnn': {'link': 'http://edition.cnn.com/'},
#  'washingtonpost': {'link': 'https://www.washingtonpost.com/',
#   'rss': 'http://feeds.washingtonpost.com/rss/world'}}

# %%
count = 1
lst = []
# Iterate through each news company
for company, value in companies.items():
    # If a RSS link is provided in the JSON file, this will be the first choice.
    # Reason for this is that, RSS feeds often give more consistent and correct data.
    # If you do not want to scrape from the RSS-feed, just leave the RSS attr empty in the JSON file.
    if 'rss' in value:
        d = fp.parse(value['rss'])
        print("Downloading articles from ", company)
        newsPaper = {
            "rss": value['rss'],
            "link": value['link'],
            "articles": []
        }
        for entry in d.entries:
            # Check if publish date is provided, if no the article is skipped.
            # This is done to keep consistency in the data and to keep the script from crashing.
            if hasattr(entry, 'published'):
                if count > LIMIT:
                    break
                article = {}
                article['link'] = entry.link
                date = entry.published_parsed
                article['published'] = datetime.fromtimestamp(mktime(date)).isoformat()
                try:
                    content = Article(entry.link)
                    content.download()
                    content.parse()
                except Exception as e:
                    # If the download for some reason fails (ex. 404) the script will continue downloading
                    # the next article.
                    print(e)
                    print("continuing...")
                    continue
                article['title'] = content.title
                article['text'] = content.text
                newsPaper['articles'].append(article)
                
                lst.append([content.title,content.text,content.url,datetime.fromtimestamp(mktime(date)).isoformat(),'RSS'])
                
                print(count, "articles downloaded from", company, ", url: ", entry.link)
                count = count + 1
                news

    else:
        # This is the fallback method if a RSS-feed link is not provided.
        # It uses the python newspaper library to extract articles
        print("Building site for ", company)
        paper = newspaper.build(value['link'], memoize_articles=False)
        newsPaper = {
            "link": value['link'],
            "articles": []
        }
        noneTypeCount = 0
        for content in paper.articles:
            if count > LIMIT:
                break
            try:
                content.download()
                content.parse()
            except Exception as e:
                print(e)
                print("continuing...")
                continue
            # Again, for consistency, if there is no found publish date the article will be skipped.
            # After 10 downloaded articles from the same newspaper without publish date, the company will be skipped.
            if content.publish_date is None:
                print(count, " Article has date of type None...")
                noneTypeCount = noneTypeCount + 1
                if noneTypeCount > 10:
                    print("Too many noneType dates, aborting...")
                    noneTypeCount = 0
                    break
                count = count + 1
                continue
            article = {}
            article['title'] = content.title
            article['text'] = content.text
            article['link'] = content.url
            article['published'] = content.publish_date.isoformat()
            
            lst.append([content.title,content.text,content.url,content.publish_date.isoformat(),'News'])
            
            newsPaper['articles'].append(article)
            print(count, "articles downloaded from", company, " using newspaper, url: ", content.url)
            count = count + 1
            noneTypeCount = 0
            news
# Out:
# Downloading articles from  bbc
# 1 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-europe-44024184
# 2 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-44026796
# 3 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-politics-44026548
# 4 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-44023411
# 5 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-middle-east-44026087
# 6 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-44026544
# 7 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-england-leeds-44025685
# 8 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/football/44025339
# 9 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-politics-44025187
# 10 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-wales-44024978
# 11 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/entertainment-arts-44024889
# 12 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/business-44006176
# 13 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/blogs-the-papers-44025996
# 14 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/disability-44004823
# 15 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-africa-44007382
# 16 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-43761093
# 17 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-us-canada-44008153
# 18 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-england-devon-44023712
# 19 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-44022190
# 20 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-europe-isle-of-man-44023367
# 21 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-43834165
# 22 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/10318089
# 23 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/stories-44007932
# 24 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/health-43966154
# 25 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/newsbeat-43991078
# 26 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/entertainment-arts-43995542
# 27 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-asia-india-43972841
# 28 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-middle-east-44013408
# 29 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/stories-44008751
# 30 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/newsbeat-44015586
# 31 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/health-43978042
# 32 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-us-canada-43997862
# 33 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-africa-44004212
# 34 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/football/43939015
# 35 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/snooker/44023793
# 36 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/football/43968265
# 37 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/football/44008282
# 38 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/boxing/44020949
# 39 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/football/43939017
# 40 articles downloaded from bbc , url:  http://www.bbc.co.uk/sport/tennis/44025075
# 41 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-asia-43496212
# 42 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-scotland-43948079
# 43 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/stories-43979225
# 44 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/stories-43877568
# 45 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-us-canada-43915187
# 46 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/world-us-canada-43541853
# 47 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/stories-43800089
# 48 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-43808007
# 49 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-wales-43716912
# 50 articles downloaded from bbc , url:  http://www.bbc.co.uk/news/uk-43545991
# Building site for  cnn
# 51 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/2017/03/04/vr/how-to-watch-vr
# 52 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.04.28.html
# 53 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.04.29.html
# 54 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.04.30.html
# 55 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.01.html
# 56 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.02.html
# 57 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.03.html
# 58 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.04.html
# 59 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.05.html
# 60 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.06.html
# 61 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/TRANSCRIPTS/2018.05.07.html
# 62 articles downloaded from cnn  using newspaper, url:  https://www.cnn.com/travel/article/hong-kong-beaches/index.html
# 63 articles downloaded from cnn  using newspaper, url:  https://www.cnn.com/travel/article/best-luxury-hotels-london/index.html
# 64 articles downloaded from cnn  using newspaper, url:  https://www.cnn.com/travel/article/jessica-nabongo-every-country/index.html
# 65 articles downloaded from cnn  using newspaper, url:  https://www.cnn.com/travel/article/santorini-wine-greece/index.html
# 66 articles downloaded from cnn  using newspaper, url:  https://www.cnn.com/travel/article/chichen-itza-mayan-ruins-mexico/index.html
# 67 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/tasting-menus/index.html
# 68 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/santorini-wine-greece/index.html
# 69 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/london-best-restaurants/index.html
# 70 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/guizhou-china-what-to-see/index.html
# 71 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/visit-korean-dmz/index.html
# 72 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/las-vegas-best-casinos/index.html
# 73 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/twa-hotel-jfk-airport-new-york/index.html
# 74 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/snohetta-planetarium-norway/index.html
# 75 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/travel/article/naturistbnb-clothing-optional/index.html
# 76  Article has date of type None...
# 77 articles downloaded from cnn  using newspaper, url:  http://commercial.cnn.com/richard-quest-explores-kangaroo-route-business-traveller
# 78 articles downloaded from cnn  using newspaper, url:  http://commercial.cnn.com/turner-international-creates-digital-advertising-unit-connect-brands-fans
# 79 articles downloaded from cnn  using newspaper, url:  http://commercial.cnn.com/cnnmoney-launches-new-digital-live-show-markets-now
# 80 articles downloaded from cnn  using newspaper, url:  http://commercial.cnn.com/cnns-innovative-cities-explores-inventions-combat-climate-change
# 81 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/kew-gardens-temperate-house-reopens/index.html
# 82 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/cruise-train-seven-stars-japan/index.html
# 83 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/david-rockefeller-art-collection-glenn-lowry/index.html
# 84 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/meghan-markle-wedding-dress-designer/index.html
# 85 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/carsten-holler-florence-experiment/index.html
# 86 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/azzedine-alaia-the-couturier-design-museum-london/index.html
# 87 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/xavier-cha-ruthless-logic/index.html
# 88 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/facial-tattoos-yumna-al-arashi/index.html
# 89 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/tom-hegen-aerial-photography/index.html
# 90 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/transcendents-southeast-asia-spirit-mediums/index.html
# 91 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/post-truth-photography/index.html
# 92 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/prison-nation-aperture-magazine/index.html
# 93 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/paolo-roversi-fashion-photography/index.html
# 94  Article has date of type None...
# 95 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/ocean-sound-recording-studio-giske/index.html
# 96 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/a-walk-with-kengo-kuma/index.html
# 97 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/milan-design-week-2018-highlights/index.html
# 98 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/donatella-versace-fashion-icon/index.html
# 99 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/aquazzura-factory-visit-details/index.html
# 100 articles downloaded from cnn  using newspaper, url:  http://edition.cnn.com/style/article/modigliani-nu-couche-breaks-record-for-highest-auction-estimate/index.html
# Downloading articles from  washingtonpost

# %%
paper = newspaper.build(value['link'], memoize_articles=False)

# %%
data['newspapers'][company] = newsPaper
try:
    with open('scraped_articles.json', 'w') as outfile:
        json.dump(data, outfile)
except Exception as e: print(e)

# %%
news = pd.DataFrame(lst,columns=['Title','Text','Link','Published','Type'])

# %%
news.head()
# Out:
#                                                Title  \
# 0  Putin set to be inaugurated for fourth term as...
# 1       Gun violence on London's streets 'must stop'
# 2  Iran nuclear deal: Johnson tells Trump 'don't ...
# 3  Britain's 'best and worst' railway stations named
# 4  Tutankhamun 'secret chamber' does not exist, r...
#
#                                                 Text  \
# 0  Media playback is unsupported on your device M...
# 1  Image copyright Press handout Image caption Rh...
# 2  Image copyright EPA/AFP\n\nBoris Johnson has u...
# 3  Image copyright Getty Images\n\nGlasgow Queen ...
# 4  Image copyright Reuters Image caption A secret...
#
#                                                 Link            Published Type
# 0    http://www.bbc.co.uk/news/world-europe-44024184  2018-05-07T01:55:34  RSS
# 1              http://www.bbc.co.uk/news/uk-44026796  2018-05-07T04:38:25  RSS
# 2     http://www.bbc.co.uk/news/uk-politics-44026548  2018-05-07T03:40:01  RSS
# 3              http://www.bbc.co.uk/news/uk-44023411  2018-05-06T23:07:32  RSS
# 4  http://www.bbc.co.uk/news/world-middle-east-44...  2018-05-06T22:55:06  RSS

# %%
news['Text']
# Out:
# 0     Media playback is unsupported on your device M...
# 1     Image copyright Press handout Image caption Rh...
# 2     Image copyright EPA/AFP\n\nBoris Johnson has u...
# 3     Image copyright Getty Images\n\nGlasgow Queen ...
# 4     Image copyright Reuters Image caption A secret...
# 5     Image copyright PA Image caption A dog walker ...
# 6     Video\n\nA support vehicle crashed through a t...
# 7     Sir Alex Ferguson presented outgoing Arsenal m...
# 8     Image copyright PA\n\nLabour peer Lord Adonis ...
# 9     Video\n\nCardiff City manager Neil Warnock's p...
# 10    Image copyright Getty Images Image caption Sur...
# 11    The price of vanilla has soared over the last ...
# 12    Image caption Theresa May is pressing ahead wi...
# 13    Image copyright Annie Segarra\n\nA US YouTuber...
# 14    I'm back and ready - Serena Williams\n\nAs she...
# 15    Video\n\nLife expectancy in Fleetwood, Lancash...
# 16    Could Trump's 'Space Force' become a reality?\...
# 17    Video\n\nA vintage light aeroplane has made an...
# 18    A photo taken by the Duchess of Cambridge of b...
# 19    Video\n\nA diver got a big seal of approval du...
# 20    Image copyright PHIL COOMES / BBC\n\nMomtaza M...
# 21    Video\n\nBritain's most-watched news channel, ...
# 22    Image copyright Colin Freeman\n\nMore than 3,0...
# 23    Image copyright Getty Images\n\nWarm and dry w...
# 24    Image copyright Marvel Studios\n\nScience fict...
# 25    Image copyright BBC / Getty\n\nThe music indus...
# 26    Image copyright Sudharak Olwe Image caption A ...
# 27    What is the Iran nuclear deal?\n\nBBC's Paul A...
# 28    Shortly after the end of World War Two a group...
# 29    Image copyright Getty Images\n\nShannon Purser...
#                             ...
# 68    (CNN) — The culinary scene in London has come ...
# 69    Editor's Note — CNN Travel's series often carr...
# 70    (CNN) — All eyes are on the Korean Demilitariz...
# 71    Las Vegas (CNN) — Between the glitz, the glam,...
# 72    (CNN) — If you remember anything about Trans W...
# 73    (CNN) — In the undisturbed countryside of Hare...
# 74    (CNN) — If getting naked is your thing, then w...
# 75    In the latest episodes of CNN’s Business Trave...
# 76    Turner International is for the first time pro...
# 77    CNNMoney is launching Markets Now, a new weekl...
# 78    By 2050, the world’s major cities will be crow...
# 79    By continuing to browse our site you agree to ...
# 80    By continuing to browse our site you agree to ...
# 81    By continuing to browse our site you agree to ...
# 82    By continuing to browse our site you agree to ...
# 83    By continuing to browse our site you agree to ...
# 84    By continuing to browse our site you agree to ...
# 85    By continuing to browse our site you agree to ...
# 86    By continuing to browse our site you agree to ...
# 87    By continuing to browse our site you agree to ...
# 88    By continuing to browse our site you agree to ...
# 89    By continuing to browse our site you agree to ...
# 90    By continuing to browse our site you agree to ...
# 91    By continuing to browse our site you agree to ...
# 92    By continuing to browse our site you agree to ...
# 93    By continuing to browse our site you agree to ...
# 94    By continuing to browse our site you agree to ...
# 95    By continuing to browse our site you agree to ...
# 96    By continuing to browse our site you agree to ...
# 97    By continuing to browse our site you agree to ...
# Name: Text, Length: 98, dtype: object

# %%
def tokenize(news_text):
     return nlp.word_tokenize(news_text)

def posTag(tokens):
    return

# %%
token = []
postag = []

for i in range(0,len(news)):
    token.append(tokenize(news['Text'].iloc[i]))

for i in range(0,len(token)):
    postag.append(nlp.pos_tag(token[i]))

# %%
postag
# Out:
# [[('Media', 'NNP'),
#   ('playback', 'NN'),
#   ('is', 'VBZ'),
#   ('unsupported', 'JJ'),
#   ('on', 'IN'),
#   ('your', 'PRP$'),
#   ('device', 'NN'),
#   ('Media', 'NNP'),
#   ('caption', 'NN'),
#   ('Police', 'NNP'),
#   ('seized', 'VBD'),
#   ('opposition', 'NN'),
#   ('leader', 'NN'),
#   ('Alexei', 'NNP'),
#   ('Navalny', 'NNP'),
#   ('at', 'IN'),
#   ('a', 'DT'),
#   ('rally', 'NN'),
#   ('in', 'IN'),
#   ('Moscow', 'NNP'),
#   ('Vladimir', 'NNP'),
#   ('Putin', 'NNP'),
#   ('is', 'VBZ'),
#   ('due', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('sworn', 'VBN'),
#   ('in', 'IN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('fourth', 'JJ'),
#   ('term', 'NN'),
#   ('as', 'IN'),
#   ('president', 'NN'),
#   ('of', 'IN'),
#   ('Russia', 'NNP'),
#   ('on', 'IN'),
#   ('Monday', 'NNP'),
#   ('after', 'IN'),
#   ('winning', 'VBG'),
#   ('the', 'DT'),
#   ('election', 'NN'),
#   ('in', 'IN'),
#   ('March', 'NNP'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('in', 'IN'),
#   ('power', 'NN'),
#   ('for', 'IN'),
#   ('18', 'CD'),
#   ('years', 'NNS'),
#   (',', ','),
#   ('whether', 'IN'),
#   ('as', 'IN'),
#   ('president', 'NN'),
#   ('or', 'CC'),
#   ('prime', 'JJ'),
#   ('minister', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('opponents', 'NNS'),
#   ('have', 'VBP'),
#   ('likened', 'VBN'),
#   ('his', 'PRP$'),
#   ('tenure', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('reign', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('tsar', 'NN'),
#   (',', ','),
#   ('or', 'CC'),
#   ('emperor', 'NN'),
#   ('.', '.'),
#   ('Riot', 'NNP'),
#   ('police', 'NNS'),
#   ('confronted', 'VBD'),
#   ('protesters', 'NNS'),
#   ('against', 'IN'),
#   ('his', 'PRP$'),
#   ('rule', 'NN'),
#   ('in', 'IN'),
#   ('Moscow', 'NNP'),
#   ('and', 'CC'),
#   ('other', 'JJ'),
#   ('Russian', 'JJ'),
#   ('cities', 'NNS'),
#   ('on', 'IN'),
#   ('Saturday', 'NNP'),
#   ('.', '.'),
#   ('There', 'EX'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('fears', 'NNS'),
#   ('of', 'IN'),
#   ('new', 'JJ'),
#   ('unrest', 'NN'),
#   ('on', 'IN'),
#   ('Monday', 'NNP'),
#   ('as', 'IN'),
#   ('he', 'PRP'),
#   ('takes', 'VBZ'),
#   ('office', 'NN'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('inauguration', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('Kremlin', 'NNP'),
#   ('in', 'IN'),
#   ('Moscow', 'NNP'),
#   ('is', 'VBZ'),
#   ('likely', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('lower-key', 'JJ'),
#   ('than', 'IN'),
#   ('in', 'IN'),
#   ('2012', 'CD'),
#   (',', ','),
#   ('AFP', 'NNP'),
#   ('news', 'NN'),
#   ('agency', 'NN'),
#   ('reports', 'NNS'),
#   ('.', '.'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('is', 'VBZ'),
#   ('only', 'RB'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('meet', 'VB'),
#   ('volunteers', 'NNS'),
#   ('who', 'WP'),
#   ('took', 'VBD'),
#   ('part', 'NN'),
#   ('in', 'IN'),
#   ('his', 'PRP$'),
#   ('election', 'NN'),
#   ('campaign', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('agency', 'NN'),
#   ('says', 'VBZ'),
#   ('.', '.'),
#   ('Why', 'WRB'),
#   ('were', 'VBD'),
#   ('there', 'EX'),
#   ('protests', 'NNS'),
#   ('?', '.'),
#   ('More', 'JJR'),
#   ('than', 'IN'),
#   ('1,000', 'CD'),
#   ('arrests', 'NNS'),
#   ('are', 'VBP'),
#   ('said', 'VBD'),
#   ('to', 'TO'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('made', 'VBN'),
#   ('in', 'IN'),
#   ('19', 'CD'),
#   ('cities', 'NNS'),
#   ('across', 'IN'),
#   ('Russia', 'NNP'),
#   ('on', 'IN'),
#   ('Saturday', 'NNP'),
#   (',', ','),
#   ('nearly', 'RB'),
#   ('half', 'NN'),
#   ('of', 'IN'),
#   ('them', 'PRP'),
#   ('in', 'IN'),
#   ('Moscow', 'NNP'),
#   ('.', '.'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('was', 'VBD'),
#   ('re-elected', 'JJ'),
#   ('president', 'NN'),
#   ('with', 'IN'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('76', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('vote', 'NN'),
#   (',', ','),
#   ('his', 'PRP$'),
#   ('best', 'JJS'),
#   ('ever', 'RB'),
#   ('election', 'NN'),
#   ('performance', 'NN'),
#   (',', ','),
#   ('but', 'CC'),
#   ('widespread', 'JJ'),
#   ('irregularities', 'NNS'),
#   ('were', 'VBD'),
#   ('reported', 'VBN'),
#   ('by', 'IN'),
#   ('some', 'DT'),
#   ('international', 'JJ'),
#   ('observers', 'NNS'),
#   ('.', '.'),
#   ('Allegations', 'NNS'),
#   ('of', 'IN'),
#   ('ballot-rigging', 'NN'),
#   ('had', 'VBD'),
#   ('dogged', 'VBN'),
#   ('previous', 'JJ'),
#   ('elections', 'NNS'),
#   ('too', 'RB'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('country', 'NN'),
#   ("'s", 'POS'),
#   ('best-known', 'JJ'),
#   ('opposition', 'NN'),
#   ('leader', 'NN'),
#   (',', ','),
#   ('Alexei', 'NNP'),
#   ('Navalny', 'NNP'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('barred', 'VBN'),
#   ('from', 'IN'),
#   ('standing', 'VBG'),
#   ('against', 'IN'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   (',', ','),
#   ('on', 'IN'),
#   ('grounds', 'NNS'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('conviction', 'NN'),
#   ('for', 'IN'),
#   ('embezzlement', 'NN'),
#   ('which', 'WDT'),
#   ('he', 'PRP'),
#   ('denies', 'VBZ'),
#   ('and', 'CC'),
#   ('alleges', 'NNS'),
#   ('was', 'VBD'),
#   ('politically', 'RB'),
#   ('motivated', 'VBN'),
#   ('.', '.'),
#   ('Mr', 'NNP'),
#   ('Navalny', 'NNP'),
#   ('was', 'VBD'),
#   ('arrested', 'VBN'),
#   ('briefly', 'NN'),
#   ('as', 'IN'),
#   ('he', 'PRP'),
#   ('tried', 'VBD'),
#   ('to', 'TO'),
#   ('join', 'VB'),
#   ('Saturday', 'NNP'),
#   ("'s", 'POS'),
#   ('unauthorised', 'JJ'),
#   ('protest', 'NN'),
#   ('rally', 'NN'),
#   ('in', 'IN'),
#   ('Moscow', 'NNP'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('slogan', 'JJ'),
#   ('``', '``'),
#   ('He', 'PRP'),
#   ("'s", 'VBZ'),
#   ('not', 'RB'),
#   ('our', 'PRP$'),
#   ('tsar', 'NN'),
#   ("''", "''"),
#   ('.', '.'),
#   ('Domestic', 'JJ'),
#   ('opponents', 'NNS'),
#   ('accuse', 'VBP'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('of', 'IN'),
#   ('undermining', 'VBG'),
#   ('democracy', 'NN'),
#   ('in', 'IN'),
#   ('Russia', 'NNP'),
#   ('-', ':'),
#   ('a', 'DT'),
#   ('policy', 'NN'),
#   ('dubbed', 'VBN'),
#   ('``', '``'),
#   ('managed', 'VBD'),
#   ('democracy', 'NN'),
#   ("''", "''"),
#   ('-', ':'),
#   ('to', 'TO'),
#   ('keep', 'VB'),
#   ('genuine', 'JJ'),
#   ('opposition', 'NN'),
#   ('parties', 'NNS'),
#   ('out', 'IN'),
#   ('of', 'IN'),
#   ('parliament', 'NN'),
#   ('and', 'CC'),
#   ('ensure', 'VB'),
#   ('that', 'IN'),
#   ('he', 'PRP'),
#   ('and', 'CC'),
#   ('his', 'PRP$'),
#   ('allies', 'NNS'),
#   ('retain', 'VBP'),
#   ('power', 'NN'),
#   ('indefinitely', 'RB'),
#   ('.', '.'),
#   ('Could', 'NNP'),
#   ('Putin', 'NNP'),
#   ('just', 'RB'),
#   ('go', 'VB'),
#   ('on', 'IN'),
#   ('and', 'CC'),
#   ('on', 'IN'),
#   ('?', '.'),
#   ('First', 'NNP'),
#   ('elected', 'VBD'),
#   ('president', 'NN'),
#   ('in', 'IN'),
#   ('2000', 'CD'),
#   (',', ','),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('renewed', 'VBD'),
#   ('his', 'PRP$'),
#   ('four-year', 'JJ'),
#   ('term', 'NN'),
#   ('in', 'IN'),
#   ('2004', 'CD'),
#   ('before', 'IN'),
#   ('stepping', 'VBG'),
#   ('aside', 'RB'),
#   ('in', 'IN'),
#   ('2008', 'CD'),
#   ('to', 'TO'),
#   ('serve', 'VB'),
#   ('as', 'IN'),
#   ('prime', 'JJ'),
#   ('minister', 'NN'),
#   ('under', 'IN'),
#   ('his', 'PRP$'),
#   ('protege', 'NN'),
#   (',', ','),
#   ('Dmitry', 'NNP'),
#   ('Medvedev', 'NNP'),
#   (',', ','),
#   ('because', 'IN'),
#   ('by', 'IN'),
#   ('law', 'NN'),
#   ('he', 'PRP'),
#   ('could', 'MD'),
#   ('only', 'RB'),
#   ('serve', 'VB'),
#   ('two', 'CD'),
#   ('consecutive', 'JJ'),
#   ('terms', 'NNS'),
#   ('.', '.'),
#   ('Few', 'NNP'),
#   ('doubted', 'VBD'),
#   ('who', 'WP'),
#   ('was', 'VBD'),
#   ('really', 'RB'),
#   ('in', 'IN'),
#   ('charge', 'NN'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('2012', 'CD'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('returned', 'VBD'),
#   ('as', 'IN'),
#   ('president', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('time', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('term', 'NN'),
#   ('of', 'IN'),
#   ('six', 'CD'),
#   ('years', 'NNS'),
#   ('.', '.'),
#   ('If', 'IN'),
#   ('and', 'CC'),
#   ('when', 'WRB'),
#   ('he', 'PRP'),
#   ('reaches', 'VBZ'),
#   ('the', 'DT'),
#   ('end', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('fourth', 'JJ'),
#   ('term', 'NN'),
#   ('in', 'IN'),
#   ('2024', 'CD'),
#   (',', ','),
#   ('the', 'DT'),
#   ('65-year-old', 'JJ'),
#   ('will', 'MD'),
#   ('have', 'VB'),
#   ('been', 'VBN'),
#   ('in', 'IN'),
#   ('power', 'NN'),
#   ('for', 'IN'),
#   ('nearly', 'RB'),
#   ('a', 'DT'),
#   ('quarter', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('century', 'NN'),
#   ('.', '.'),
#   ('That', 'WDT'),
#   ('would', 'MD'),
#   ('still', 'RB'),
#   ('fall', 'VB'),
#   ('short', 'JJ'),
#   ('of', 'IN'),
#   ('Soviet', 'JJ'),
#   ('dictator', 'NN'),
#   ('Joseph', 'NNP'),
#   ('Stalin', 'NNP'),
#   ("'s", 'POS'),
#   ('31', 'CD'),
#   ('years', 'NNS'),
#   ('in', 'IN'),
#   ('power', 'NN'),
#   ('or', 'CC'),
#   (',', ','),
#   ('indeed', 'RB'),
#   (',', ','),
#   ('the', 'DT'),
#   ('reigns', 'NN'),
#   ('of', 'IN'),
#   ('some', 'DT'),
#   ('Russian', 'JJ'),
#   ('tsars', 'NNS'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   ('Alexander', 'NNP'),
#   ('II', 'NNP'),
#   ('(', '('),
#   ('26', 'CD'),
#   ('years', 'NNS'),
#   (')', ')'),
#   ('and', 'CC'),
#   ('Nicholas', 'NNP'),
#   ('I', 'PRP'),
#   ('(', '('),
#   ('30', 'CD'),
#   ('years', 'NNS'),
#   (')', ')'),
#   ('.', '.'),
#   ('Spy', 'NNP'),
#   ('turned', 'VBD'),
#   ('president', 'NN'),
#   ('Image', 'NNP'),
#   ('copyright', 'VBD'),
#   ('Reuters', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('Visiting', 'VBG'),
#   ('a', 'DT'),
#   ('shooting', 'JJ'),
#   ('gallery', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('GRU', 'NNP'),
#   ('military', 'JJ'),
#   ('intelligence', 'NN'),
#   ('headquarters', 'NNS'),
#   ('in', 'IN'),
#   ('Moscow', 'NNP'),
#   ('in', 'IN'),
#   ('2006', 'CD'),
#   ('1952', 'CD'),
#   (':', ':'),
#   ('Born', 'VBN'),
#   ('7', 'CD'),
#   ('October', 'NNP'),
#   ('in', 'IN'),
#   ('Leningrad', 'NNP'),
#   ('(', '('),
#   ('now', 'RB'),
#   ('St', 'NNP'),
#   ('Petersburg', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('Russia', 'NNP'),
#   ("'s", 'POS'),
#   ('second', 'JJ'),
#   ('city', 'NN'),
#   (',', ','),
#   ('studies', 'NNS'),
#   ('law', 'NN'),
#   ('and', 'CC'),
#   ('joins', 'VBZ'),
#   ('KGB', 'NNP'),
#   ('secret', 'JJ'),
#   ('police', 'NN'),
#   (',', ','),
#   ('serving', 'VBG'),
#   ('as', 'IN'),
#   ('spy', 'NN'),
#   ('in', 'IN'),
#   ('communist', 'JJ'),
#   ('East', 'NNP'),
#   ('Germany', 'NNP'),
#   ('1990s', 'CD'),
#   (':', ':'),
#   ('After', 'IN'),
#   ('serving', 'VBG'),
#   ('as', 'RB'),
#   ('top', 'JJ'),
#   ('aide', 'NN'),
#   ('to', 'TO'),
#   ('mayor', 'NN'),
#   ('of', 'IN'),
#   ('St', 'NNP'),
#   ('Petersburg', 'NNP'),
#   (',', ','),
#   ('enters', 'NNS'),
#   ('Boris', 'NNP'),
#   ('Yeltsin', 'NNP'),
#   ("'s", 'POS'),
#   ('Kremlin', 'NNP'),
#   ('in', 'IN'),
#   ('1997', 'CD'),
#   (',', ','),
#   ('where', 'WRB'),
#   ('he', 'PRP'),
#   ('is', 'VBZ'),
#   ('made', 'VBN'),
#   ('chief', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('FSB', 'NNP'),
#   ('(', '('),
#   ('the', 'DT'),
#   ('KGB', 'NNP'),
#   ("'s", 'POS'),
#   ('successor', 'NN'),
#   (')', ')'),
#   ('1999', 'CD'),
#   (':', ':'),
#   ('Appointed', 'VBN'),
#   ('prime', 'JJ'),
#   ('minister', 'NN'),
#   (',', ','),
#   ('becomes', 'VBZ'),
#   ('acting', 'VBG'),
#   ('president', 'NN'),
#   ('upon', 'IN'),
#   ('Yeltsin', 'NNP'),
#   ("'s", 'POS'),
#   ('resignation', 'NN'),
#   ('2000', 'CD'),
#   (':', ':'),
#   ('Elected', 'VBN'),
#   ('president', 'NN'),
#   ('and', 'CC'),
#   ('serves', 'VBZ'),
#   ('two', 'CD'),
#   ('four-year', 'JJ'),
#   ('terms', 'NNS'),
#   ('2008', 'CD'),
#   (':', ':'),
#   ('Barred', 'VBN'),
#   ('from', 'IN'),
#   ('running', 'VBG'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('third', 'JJ'),
#   ('consecutive', 'JJ'),
#   ('term', 'NN'),
#   (',', ','),
#   ('stuns', 'JJ'),
#   ('analysts', 'NNS'),
#   ('by', 'IN'),
#   ('returning', 'VBG'),
#   ('to', 'TO'),
#   ('post', 'NN'),
#   ('of', 'IN'),
#   ('prime', 'JJ'),
#   ('minister', 'NN'),
#   ('while', 'IN'),
#   ('his', 'PRP$'),
#   ('protege', 'NN'),
#   ('Dmitry', 'NNP'),
#   ('Medvedev', 'NNP'),
#   ('becomes', 'VBZ'),
#   ('president', 'NN'),
#   ('2012', 'CD'),
#   (':', ':'),
#   ('Re-elected', 'JJ'),
#   ('president', 'NN'),
#   ('and', 'CC'),
#   ('for', 'IN'),
#   ('term', 'NN'),
#   ('of', 'IN'),
#   ('six', 'CD'),
#   ('years', 'NNS'),
#   (',', ','),
#   ('under', 'IN'),
#   ('new', 'JJ'),
#   ('law', 'NN'),
#   ('2018', 'CD'),
#   (':', ':'),
#   ('Re-elected', 'JJ'),
#   ('for', 'IN'),
#   ('fourth', 'JJ'),
#   ('term', 'NN'),
#   ('How', 'NNP'),
#   ('has', 'VBZ'),
#   ('Russia', 'VBN'),
#   ('changed', 'VBN'),
#   ('under', 'IN'),
#   ('Putin', 'NNP'),
#   ('?', '.'),
#   ('Ordinary', 'JJ'),
#   ('Russians', 'NNPS'),
#   ('welcomed', 'VBD'),
#   ('the', 'DT'),
#   ('stability', 'NN'),
#   ('associated', 'VBN'),
#   ('with', 'IN'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ("'s", 'POS'),
#   ('early', 'JJ'),
#   ('years', 'NNS'),
#   ('in', 'IN'),
#   ('office', 'NN'),
#   ('when', 'WRB'),
#   ('inflation', 'NN'),
#   ('was', 'VBD'),
#   ('reined', 'VBN'),
#   ('in', 'IN'),
#   ('and', 'CC'),
#   ('basic', 'JJ'),
#   ('state', 'NN'),
#   ('functions', 'NNS'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('welfare', 'NN'),
#   ('system', 'NN'),
#   ('were', 'VBD'),
#   ('shored', 'VBN'),
#   ('up', 'RP'),
#   ('.', '.'),
#   ('Separatist', 'JJ'),
#   ('violence', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('North', 'NNP'),
#   ('Caucasus', 'NNP'),
#   ('which', 'WDT'),
#   ('had', 'VBD'),
#   ('plagued', 'VBN'),
#   ('the', 'DT'),
#   ('administration', 'NN'),
#   ('of', 'IN'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ("'s", 'POS'),
#   ('predecessor', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('late', 'JJ'),
#   ('Boris', 'NNP'),
#   ('Yeltsin', 'NNP'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('finally', 'RB'),
#   ('brought', 'VBN'),
#   ('to', 'TO'),
#   ('a', 'DT'),
#   ('bloody', 'JJ'),
#   ('end', 'NN'),
#   ('.', '.'),
#   ('Image', 'NNP'),
#   ('copyright', 'VBD'),
#   ('Reuters', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('With', 'IN'),
#   ('President', 'NNP'),
#   ('Bashar', 'NNP'),
#   ('al-Assad', 'NN'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('visit', 'NN'),
#   ('to', 'TO'),
#   ('Syria', 'NNP'),
#   ('in', 'IN'),
#   ('2017', 'CD'),
#   ('As', 'IN'),
#   ('prosperity', 'NN'),
#   ('grew', 'VBD'),
#   (',', ','),
#   ('fuelled', 'VBN'),
#   ('by', 'IN'),
#   ('oil', 'NN'),
#   ('and', 'CC'),
#   ('gas', 'NN'),
#   ('revenue', 'NN'),
#   (',', ','),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('oversaw', 'VBD'),
#   ('an', 'DT'),
#   ('increase', 'NN'),
#   ('in', 'IN'),
#   ('state', 'NN'),
#   ('power', 'NN'),
#   (',', ','),
#   ('rolling', 'VBG'),
#   ('back', 'RP'),
#   ('independent', 'JJ'),
#   ('media', 'NNS'),
#   ('as', 'RB'),
#   ('well', 'RB'),
#   ('as', 'IN'),
#   ('political', 'JJ'),
#   ('freedoms', 'NNS'),
#   ('.', '.'),
#   ('His', 'PRP$'),
#   ('decision', 'NN'),
#   ('to', 'TO'),
#   ('annex', 'VB'),
#   ('Crimea', 'NNP'),
#   ('from', 'IN'),
#   ('Ukraine', 'NNP'),
#   ('in', 'IN'),
#   ('2014', 'CD'),
#   ('sparked', 'VBD'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('biggest', 'JJS'),
#   ('international', 'JJ'),
#   ('crises', 'NNS'),
#   ('since', 'IN'),
#   ('the', 'DT'),
#   ('Cold', 'NNP'),
#   ('War', 'NNP'),
#   (',', ','),
#   ('incurring', 'VBG'),
#   ('Western', 'JJ'),
#   ('sanctions', 'NNS'),
#   ('which', 'WDT'),
#   ('continue', 'VBP'),
#   ('to', 'TO'),
#   ('this', 'DT'),
#   ('day', 'NN'),
#   ('.', '.'),
#   ('Russia', 'NNP'),
#   ("'s", 'POS'),
#   ('alleged', 'JJ'),
#   ('interference', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('2016', 'CD'),
#   ('US', 'NNP'),
#   ('presidential', 'JJ'),
#   ('election', 'NN'),
#   ('soured', 'VBD'),
#   ('international', 'JJ'),
#   ('relations', 'NNS'),
#   ('even', 'RB'),
#   ('further', 'RBR'),
#   (',', ','),
#   ('while', 'IN'),
#   ('this', 'DT'),
#   ('year', 'NN'),
#   ('saw', 'VBD'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ('accused', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('UK', 'NNP'),
#   ('of', 'IN'),
#   ('responsibility', 'NN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('nerve', 'NN'),
#   ('agent', 'NN'),
#   ('attack', 'NN'),
#   ('on', 'IN'),
#   ('its', 'PRP$'),
#   ('soil', 'NN'),
#   ('-', ':'),
#   ('allegations', 'NNS'),
#   ('denied', 'VBN'),
#   ('by', 'IN'),
#   ('Moscow', 'NNP'),
#   ('.', '.'),
#   ('Political', 'JJ'),
#   ('analyst', 'NN'),
#   ('Dmitry', 'NNP'),
#   ('Oreshkin', 'NNP'),
#   ('told', 'VBD'),
#   ('AFP', 'NNP'),
#   ('Mr', 'NNP'),
#   ('Putin', 'NNP'),
#   ("'s", 'POS'),
#   ('approach', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('international', 'JJ'),
#   ('community', 'NN'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('to', 'TO'),
#   ('change', 'VB'),
#   ('over', 'IN'),
#   ('his', 'PRP$'),
#   ('new', 'JJ'),
#   ('term', 'NN'),
#   ('.', '.'),
#   ('``', '``'),
#   ('Russia', 'NNP'),
#   ('has', 'VBZ'),
#   ("n't", 'RB'),
#   ('been', 'VBN'),
#   ('so', 'RB'),
#   ('isolated', 'JJ'),
#   ('since', 'IN'),
#   ('the', 'DT'),
#   ('Soviet', 'NNP'),
#   ('war', 'NN'),
#   ('in', 'IN'),
#   ('Afghanistan', 'NNP'),
#   (',', ','),
#   ("''", "''"),
#   ('he', 'PRP'),
#   ('said', 'VBD'),
#   ('.', '.'),
#   ('``', '``'),
#   ('Now', 'RB'),
#   ('his', 'PRP$'),
#   ('[', 'NN'),
#   ('Putin', 'NNP'),
#   ("'s", 'POS'),
#   (']', 'NNP'),
#   ('task', 'NN'),
#   ('is', 'VBZ'),
#   ("n't", 'RB'),
#   ('to', 'TO'),
#   ('bring', 'VB'),
#   ('any', 'DT'),
#   ('new', 'JJ'),
#   ('lands', 'NNS'),
#   ('to', 'TO'),
#   ('Russia', 'VB'),
#   ('but', 'CC'),
#   ('to', 'TO'),
#   ('force', 'VB'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('to', 'TO'),
#   ('consider', 'VB'),
#   ('Russia', 'NNP'),
#   ("'s", 'POS'),
#   ('interests', 'NNS'),
#   ('and', 'CC'),
#   ('accept', 'VB'),
#   ('its', 'PRP$'),
#   ('previous', 'JJ'),
#   ('conquests', 'NNS'),
#   (',', ','),
#   ("''", "''"),
#   ('Oreshkin', 'NNP'),
#   ('added', 'VBD'),
#   ('.', '.')],
#  [('Image', 'NNP'),
#   ('copyright', 'VBD'),
#   ('Press', 'NNP'),
#   ('handout', 'NN'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('Rhyhiem', 'NNP'),
#   ('Ainsworth', 'NNP'),
#   ('Barton', 'NNP'),
#   ('was', 'VBD'),
#   ('``', '``'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('make', 'VB'),
#   ('a', 'DT'),
#   ('difference', 'NN'),
#   ("''", "''"),
#   ('by', 'IN'),
#   ('learning', 'VBG'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('with', 'IN'),
#   ('children', 'NNS'),
#   (',', ','),
#   ('his', 'PRP$'),
#   ('mother', 'NN'),
#   ('said', 'VBD'),
#   ('The', 'DT'),
#   ('mother', 'NN'),
#   ('of', 'IN'),
#   ('a', 'DT'),
#   ('17-year-old', 'JJ'),
#   ('boy', 'NN'),
#   ('who', 'WP'),
#   ('was', 'VBD'),
#   ('killed', 'VBN'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('weekend', 'NN'),
#   ('has', 'VBZ'),
#   ('called', 'VBN'),
#   ('for', 'IN'),
#   ('an', 'DT'),
#   ('end', 'NN'),
#   ('to', 'TO'),
#   ('violence', 'NN'),
#   ('on', 'IN'),
#   ('London', 'NNP'),
#   ("'s", 'POS'),
#   ('streets', 'NNS'),
#   ('.', '.'),
#   ('``', '``'),
#   ('Let', 'VB'),
#   ('my', 'PRP$'),
#   ('son', 'NN'),
#   ('be', 'VB'),
#   ('the', 'DT'),
#   ('last', 'JJ'),
#   ('and', 'CC'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('example', 'NN'),
#   ('to', 'TO'),
#   ('everyone', 'NN'),
#   ('.', '.'),
#   ('Just', 'NNP'),
#   ('let', 'VB'),
#   ('it', 'PRP'),
#   ('stop', 'VB'),
#   (',', ','),
#   ("''", "''"),
#   ('said', 'VBD'),
#   ('Pretana', 'NNP'),
#   ('Morgan', 'NNP'),
#   (',', ','),
#   ('whose', 'WP$'),
#   ('son', 'NN'),
#   ('Rhyhiem', 'NNP'),
#   ('was', 'VBD'),
#   ('shot', 'VBN'),
#   ('dead', 'JJ'),
#   ('in', 'IN'),
#   ('Southwark', 'NNP'),
#   ('on', 'IN'),
#   ('Saturday', 'NNP'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('teenager', 'NN'),
#   ('was', 'VBD'),
#   ('one', 'CD'),
#   ('of', 'IN'),
#   ('four', 'CD'),
#   ('people', 'NNS'),
#   ('shot', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('capital', 'NN'),
#   ('over', 'IN'),
#   ('the', 'DT'),
#   ('bank', 'NN'),
#   ('holiday', 'NN'),
#   ('weekend', 'NN'),
#   ('.', '.'),
#   ('In', 'IN'),
#   ('Wealdstone', 'NNP'),
#   (',', ','),
#   ('two', 'CD'),
#   ('boys', 'NNS'),
#   (',', ','),
#   ('aged', 'VBD'),
#   ('13', 'CD'),
#   ('and', 'CC'),
#   ('15', 'CD'),
#   (',', ','),
#   ('suffered', 'VBD'),
#   ('head', 'NN'),
#   ('injuries', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('a', 'DT'),
#   ('22-year-old', 'JJ'),
#   ('was', 'VBD'),
#   ('shot', 'VBN'),
#   ('in', 'IN'),
#   ('Lewisham', 'NNP'),
#   ('.', '.'),
#   ('None', 'NN'),
#   ('of', 'IN'),
#   ('them', 'PRP'),
#   ('have', 'VBP'),
#   ('injuries', 'NNS'),
#   ('which', 'WDT'),
#   ('are', 'VBP'),
#   ('considered', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('life-threatening', 'JJ'),
#   ('.', '.'),
#   ('Image', 'NN'),
#   ('copyright', 'NN'),
#   ('Reuters', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('Pretana', 'NNP'),
#   ('Morgan', 'NNP'),
#   ('(', '('),
#   ('r', 'NN'),
#   (')', ')'),
#   ('is', 'VBZ'),
#   ('comforted', 'VBN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('scene', 'NN'),
#   ('of', 'IN'),
#   ('her', 'PRP$'),
#   ('son', 'NN'),
#   ("'s", 'POS'),
#   ('death', 'NN'),
#   ('Rhyhiem', 'NNP'),
#   ('Ainsworth', 'NNP'),
#   ('Barton', 'NNP'),
#   ('was', 'VBD'),
#   ('found', 'VBN'),
#   ('in', 'IN'),
#   ('Warham', 'NNP'),
#   ('Street', 'NNP'),
#   (',', ','),
#   ('Southwark', 'NNP'),
#   (',', ','),
#   ('after', 'IN'),
#   ('a', 'DT'),
#   ('reported', 'JJ'),
#   ('shooting', 'NN'),
#   ('in', 'IN'),
#   ('nearby', 'JJ'),
#   ('Cooks', 'NNP'),
#   ('Road', 'NNP'),
#   ('on', 'IN'),
#   ('Saturday', 'NNP'),
#   ('evening', 'NN'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('was', 'VBD'),
#   ('hit', 'VBN'),
#   ('while', 'IN'),
#   ('playing', 'VBG'),
#   ('football', 'NN'),
#   ('with', 'IN'),
#   ('friends', 'NNS'),
#   ('and', 'CC'),
#   ('died', 'VBD'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('scene', 'NN'),
#   ('shortly', 'RB'),
#   ('before', 'IN'),
#   ('19:00', 'CD'),
#   ('BST', 'NNP'),
#   ('.', '.'),
#   ('Witnesses', 'NNS'),
#   ('told', 'VBD'),
#   ('the', 'DT'),
#   ('BBC', 'NNP'),
#   ('a', 'DT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('shots', 'NNS'),
#   ('were', 'VBD'),
#   ('fired', 'VBN'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('street', 'NN'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('one', 'CD'),
#   ('that', 'WDT'),
#   ('missed', 'VBD'),
#   ('a', 'DT'),
#   ('woman', 'NN'),
#   ('and', 'CC'),
#   ('went', 'VBD'),
#   ('through', 'IN'),
#   ('a', 'DT'),
#   ('window', 'NN'),
#   ('.', '.'),
#   ('No', 'DT'),
#   ('arrests', 'NNS'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('made', 'VBN'),
#   ('as', 'IN'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('murder', 'NN'),
#   ('probe', 'NN'),
#   ('.', '.'),
#   ('His', 'PRP$'),
#   ('mother', 'NN'),
#   (',', ','),
#   ('Pretana', 'NNP'),
#   ('Morgan', 'NNP'),
#   (',', ','),
#   ('said', 'VBD'),
#   ('she', 'PRP'),
#   ('``', '``'),
#   ('could', 'MD'),
#   ("n't", 'RB'),
#   ('have', 'VB'),
#   ('asked', 'VBN'),
#   ('for', 'IN'),
#   ('a', 'DT'),
#   ('better', 'JJR'),
#   ('son', 'NN'),
#   ("''", "''"),
#   ('.', '.'),
#   ('She', 'PRP'),
#   ('said', 'VBD'),
#   ('he', 'PRP'),
#   ('was', 'VBD'),
#   ('not', 'RB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('gang', 'NN'),
#   ('and', 'CC'),
#   ('aspired', 'VBD'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('an', 'DT'),
#   ('architect', 'NN'),
#   ('.', '.'),
#   ('Borough', 'NNP'),
#   ('commander', 'NN'),
#   ('Simon', 'NNP'),
#   ('Messinger', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('violence', 'NN'),
#   ('had', 'VBD'),
#   ('``', '``'),
#   ('rightly', 'RB'),
#   ('caused', 'VBD'),
#   ('concern', 'NN'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('``', '``'),
#   ('fast-paced', 'JJ'),
#   ("''", "''"),
#   ('investigation', 'NN'),
#   ('was', 'VBD'),
#   ('``', '``'),
#   ('progressing', 'VBG'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('time', 'NN'),
#   ("''", "''"),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('said', 'VBD'),
#   ('additional', 'JJ'),
#   ('officers', 'NNS'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('on', 'IN'),
#   ('patrol', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('rest', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('weekend', 'NN'),
#   (',', ','),
#   ('supported', 'VBN'),
#   ('by', 'IN'),
#   ('armed', 'JJ'),
#   ('response', 'NN'),
#   ('officers', 'NNS'),
#   ('on', 'IN'),
#   ('motorcycles', 'NNS'),
#   (',', ','),
#   ('dog', 'JJ'),
#   ('units', 'NNS'),
#   ('and', 'CC'),
#   ('air', 'NN'),
#   ('support', 'NN'),
#   ('.', '.'),
#   ('London', 'NNP'),
#   ('Mayor', 'NNP'),
#   ('Sadiq', 'NNP'),
#   ('Khan', 'NNP'),
#   ('said', 'VBD'),
#   ('his', 'PRP$'),
#   ('thoughts', 'NNS'),
#   ('go', 'VB'),
#   ('out', 'RB'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('``', '``'),
#   ('loved', 'JJ'),
#   ('ones', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('teenager', 'NN'),
#   ('who', 'WP'),
#   ('was', 'VBD'),
#   ('tragically', 'RB'),
#   ('killed', 'VBN'),
#   ("''", "''"),
#   ('.', '.'),
#   ('Image', 'NNP'),
#   ('copyright', 'VBD'),
#   ('PA', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('A', 'NNP'),
#   ('police', 'NN'),
#   ('team', 'NN'),
#   ('is', 'VBZ'),
#   ('searching', 'VBG'),
#   ('the', 'DT'),
#   ('scene', 'NN'),
#   ('outside', 'IN'),
#   ('Aberfeldy', 'NNP'),
#   ('House', 'NNP'),
#   ('in', 'IN'),
#   ('Camberwell', 'NNP'),
#   ('New', 'NNP'),
#   ('Road', 'NNP'),
#   ('Rhyheim', 'NNP'),
#   ("'s", 'POS'),
#   ('death', 'NN'),
#   ('came', 'VBD'),
#   ('less', 'JJR'),
#   ('than', 'IN'),
#   ('24', 'CD'),
#   ('hours', 'NNS'),
#   ('before', 'IN'),
#   ('two', 'CD'),
#   ('other', 'JJ'),
#   ('teenage', 'NN'),
#   ('boys', 'NNS'),
#   ('were', 'VBD'),
#   ('shot', 'VBN'),
#   ('in', 'IN'),
#   ('broad', 'JJ'),
#   ('daylight', 'NN'),
#   ('-', ':'),
#   ('around', 'IN'),
#   ('Sunday', 'NNP'),
#   ('lunchtime', 'SYM'),
#   ('-', ':'),
#   ('on', 'IN'),
#   ('a', 'DT'),
#   ('street', 'NN'),
#   ('in', 'IN'),
#   ('north-west', 'JJ'),
#   ('London', 'NNP'),
#   ('.', '.'),
#   ('A', 'DT'),
#   ('13-year-old', 'JJ'),
#   ('boy', 'NN'),
#   ('suffered', 'VBD'),
#   ('a', 'DT'),
#   ('shotgun', 'JJ'),
#   ('pellet', 'NN'),
#   ('wound', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('head', 'NN'),
#   ('within', 'IN'),
#   ('minutes', 'NNS'),
#   ('of', 'IN'),
#   ('another', 'DT'),
#   ('teenager', 'NN'),
#   (',', ','),
#   ('aged', 'VBD'),
#   ('15', 'CD'),
#   (',', ','),
#   ('also', 'RB'),
#   ('being', 'VBG'),
#   ('injured', 'VBN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('gun', 'JJ'),
#   ('attack', 'NN'),
#   ('.', '.'),
#   ('Both', 'DT'),
#   ('boys', 'NNS'),
#   ('remain', 'VBP'),
#   ('in', 'IN'),
#   ('hospital', 'NN'),
#   ('.', '.'),
#   ('A', 'DT'),
#   ('Scotland', 'NNP'),
#   ('Yard', 'NNP'),
#   ('spokeswoman', 'NN'),
#   ('said', 'VBD'),
#   ('they', 'PRP'),
#   ('were', 'VBD'),
#   ('investigating', 'VBG'),
#   ('whether', 'IN'),
#   ('the', 'DT'),
#   ('incidents', 'NNS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('occurred', 'VBD'),
#   ('at', 'IN'),
#   ('two', 'CD'),
#   ('separate', 'JJ'),
#   ('locations', 'NNS'),
#   ('on', 'IN'),
#   ('Wealdstone', 'NNP'),
#   ('High', 'NNP'),
#   ('Street', 'NNP'),
#   (',', ','),
#   ('were', 'VBD'),
#   ('linked', 'VBN'),
#   ('.', '.'),
#   ('Image', 'NNP'),
#   ('copyright', 'VBD'),
#   ('PA', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('The', 'DT'),
#   ('two', 'CD'),
#   ('boys', 'NNS'),
#   ('were', 'VBD'),
#   ('shot', 'VBN'),
#   ('on', 'IN'),
#   ('Wealdstone', 'NNP'),
#   ('High', 'NNP'),
#   ('Street', 'NNP'),
#   ('A', 'NNP'),
#   ('shopkeeper', 'NN'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('13-year-old', 'JJ'),
#   ('was', 'VBD'),
#   ('``', '``'),
#   ('lucky', 'JJ'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('alive', 'JJ'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('they', 'PRP'),
#   ('believed', 'VBD'),
#   ('a', 'DT'),
#   ('bullet', 'NN'),
#   ('had', 'VBD'),
#   ('grazed', 'VBN'),
#   ('the', 'DT'),
#   ('back', 'NN'),
#   ('of', 'IN'),
#   ('his', 'PRP$'),
#   ('head', 'NN'),
#   ('.', '.'),
#   ('In', 'IN'),
#   ('a', 'DT'),
#   ('separate', 'JJ'),
#   ('attack', 'NN'),
#   (',', ','),
#   ('a', 'DT'),
#   ('22-year-old', 'JJ'),
#   ('suffered', 'JJ'),
#   ('non', 'IN'),
#   ('life-threatening', 'JJ'),
#   ('wounds', 'NNS'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('shooting', 'NN'),
#   ('in', 'IN'),
#   ('New', 'NNP'),
#   ('Cross', 'NNP'),
#   ('Road', 'NNP'),
#   (',', ','),
#   ('Lewisham', 'NNP'),
#   (',', ','),
#   ('at', 'IN'),
#   ('about', 'RB'),
#   ('18:30', 'CD'),
#   ('.', '.'),
#   ('There', 'EX'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('no', 'DT'),
#   ('arrests', 'NNS'),
#   ('in', 'IN'),
#   ('any', 'DT'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('cases', 'NNS'),
#   ('.', '.'),
#   ('Labour', 'NNP'),
#   ('MP', 'NNP'),
#   ('David', 'NNP'),
#   ('Lammy', 'NNP'),
#   ('tweeted', 'VBD'),
#   (':', ':'),
#   ('``', '``'),
#   ('Enough', 'NNP'),
#   ('.', '.'),
#   ('Enough', 'NNP'),
#   ('.', '.'),
#   ('My', 'NNP'),
#   ('heart', 'NN'),
#   ('goes', 'VBZ'),
#   ('out', 'RP'),
#   ('to', 'TO'),
#   ('families', 'NNS'),
#   ('grieving', 'VBG'),
#   ('children', 'NNS'),
#   ('and', 'CC'),
#   ('teenagers', 'NNS'),
#   ('.', '.'),
#   ('So', 'RB'),
#   ('many', 'JJ'),
#   ('shattered', 'JJ'),
#   ('lives', 'NNS'),
#   (',', ','),
#   ('families', 'NNS'),
#   ('and', 'CC'),
#   ('communities', 'NNS'),
#   ('.', '.'),
#   ("''", "''"),
#   ('Official', 'JJ'),
#   ('statistics', 'NNS'),
#   ('released', 'VBN'),
#   ('in', 'IN'),
#   ('April', 'NNP'),
#   ('showed', 'VBD'),
#   ('the', 'DT'),
#   ('number', 'NN'),
#   ('of', 'IN'),
#   ('homicides', 'NNS'),
#   ('in', 'IN'),
#   ('London', 'NNP'),
#   ('had', 'VBD'),
#   ('surged', 'VBD'),
#   ('by', 'IN'),
#   ('44', 'CD'),
#   ('%', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('than', 'IN'),
#   ('60', 'CD'),
#   ('people', 'NNS'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('killed', 'VBN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('capital', 'NN'),
#   ('this', 'DT'),
#   ('year', 'NN'),
#   ('-', ':'),
#   ('about', 'IN'),
#   ('half', 'NN'),
#   ('were', 'VBD'),
#   ('the', 'DT'),
#   ('result', 'NN'),
#   ('of', 'IN'),
#   ('stabbings', 'NNS'),
#   ('.', '.'),
#   ('Around', 'IN'),
#   ('the', 'DT'),
#   ('UK', 'NNP'),
#   (',', ','),
#   ('two', 'CD'),
#   ('men', 'NNS'),
#   ('died', 'VBD'),
#   ('in', 'IN'),
#   ('stabbings', 'NNS'),
#   ('in', 'IN'),
#   ('Liverpool', 'NNP'),
#   ('and', 'CC'),
#   ('Luton', 'NNP'),
#   ('across', 'IN'),
#   ('the', 'DT'),
#   ('bank', 'NN'),
#   ('holiday', 'NN'),
#   ('weekend', 'NN'),
#   ('.', '.'),
#   ('A', 'DT'),
#   ('20-year-old', 'JJ'),
#   ('man', 'NN'),
#   ('died', 'VBD'),
#   ('after', 'IN'),
#   ('being', 'VBG'),
#   ('stabbed', 'VBN'),
#   ('in', 'IN'),
#   ('Liverpool', 'NNP'),
#   ('city', 'NN'),
#   ('centre', 'VBP'),
#   ('early', 'RB'),
#   ('on', 'IN'),
#   ('Sunday', 'NNP'),
#   (',', ','),
#   ('while', 'IN'),
#   ('another', 'DT'),
#   ('victim', 'NN'),
#   (',', ','),
#   ('also', 'RB'),
#   ('aged', 'VBD'),
#   ('20', 'CD'),
#   (',', ','),
#   ('was', 'VBD'),
#   ('killed', 'VBN'),
#   ('in', 'IN'),
#   ('Bishopscote', 'NNP'),
#   ('Road', 'NNP'),
#   ('in', 'IN'),
#   ('Luton', 'NNP'),
#   ('on', 'IN'),
#   ('Sunday', 'NNP'),
#   ('evening', 'NN'),
#   ('.', '.')],
#  [('Image', 'NN'),
#   ('copyright', 'VBD'),
#   ('EPA/AFP', 'NNP'),
#   ('Boris', 'NNP'),
#   ('Johnson', 'NNP'),
#   ('has', 'VBZ'),
#   ('urged', 'VBN'),
#   ('President', 'NNP'),
#   ('Trump', 'NNP'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('give', 'VB'),
#   ('up', 'RP'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Iran', 'NNP'),
#   ('nuclear', 'JJ'),
#   ('deal', 'NN'),
#   (',', ','),
#   ('saying', 'VBG'),
#   ('``', '``'),
#   ('at', 'IN'),
#   ('this', 'DT'),
#   ('delicate', 'JJ'),
#   ('juncture', 'NN'),
#   ('it', 'PRP'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('a', 'DT'),
#   ('mistake', 'NN'),
#   ('to', 'TO'),
#   ('walk', 'VB'),
#   ('away', 'RB'),
#   ("''", "''"),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('foreign', 'JJ'),
#   ('secretary', 'NN'),
#   ('is', 'VBZ'),
#   ('in', 'IN'),
#   ('Washington', 'NNP'),
#   ('to', 'TO'),
#   ('persuade', 'VB'),
#   ('the', 'DT'),
#   ('US', 'NNP'),
#   ('president', 'NN'),
#   ('to', 'TO'),
#   ('remain', 'VB'),
#   ('a', 'DT'),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('international', 'JJ'),
#   ('accord', 'NN'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('deal', 'NN'),
#   ('saw', 'NN'),
#   ('Iran', 'NNP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('limit', 'VB'),
#   ('its', 'PRP$'),
#   ('nuclear', 'JJ'),
#   ('activities', 'NNS'),
#   ('in', 'IN'),
#   ('return', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('easing', 'NN'),
#   ('of', 'IN'),
#   ('sanctions', 'NNS'),
#   ('on', 'IN'),
#   ('its', 'PRP$'),
#   ('economy', 'NN'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('UK', 'NNP'),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('European', 'JJ'),
#   ('allies', 'NNS'),
#   ('have', 'VBP'),
#   ('until', 'IN'),
#   ('12', 'CD'),
#   ('May', 'NNP'),
#   ('to', 'TO'),
#   ('persuade', 'VB'),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('to', 'TO'),
#   ('stick', 'VB'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('deal', 'NN'),
#   ('.', '.'),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('has', 'VBZ'),
#   ('strongly', 'RB'),
#   ('criticised', 'VBN'),
#   ('the', 'DT'),
#   ('agreement', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('he', 'PRP'),
#   ('calls', 'VBZ'),
#   ('``', '``'),
#   ('insane', 'NN'),
#   ("''", "''"),
#   ('.', '.'),
#   ('Britain', 'NNP'),
#   (',', ','),
#   ('France', 'NNP'),
#   ('and', 'CC'),
#   ('Germany', 'NNP'),
#   ('have', 'VBP'),
#   ('been', 'VBN'),
#   ('working', 'VBG'),
#   ('behind', 'IN'),
#   ('the', 'DT'),
#   ('scenes', 'NNS'),
#   ('for', 'IN'),
#   ('weeks', 'NNS'),
#   ('in', 'IN'),
#   ('an', 'DT'),
#   ('effort', 'NN'),
#   ('to', 'TO'),
#   ('preserve', 'VB'),
#   ('the', 'DT'),
#   ('deal', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('was', 'VBD'),
#   ('orchestrated', 'VBN'),
#   ('under', 'IN'),
#   ('the', 'DT'),
#   ('Obama', 'NNP'),
#   ('administration', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('includes', 'VBZ'),
#   ('Russia', 'NNP'),
#   ('and', 'CC'),
#   ('China', 'NNP'),
#   ('as', 'IN'),
#   ('signatories', 'NNS'),
#   ('.', '.'),
#   ("'Handcuffs", 'NNS'),
#   ('are', 'VBP'),
#   ('in', 'IN'),
#   ("place'", 'NN'),
#   ('Writing', 'NNP'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('New', 'NNP'),
#   ('York', 'NNP'),
#   ('Times', 'NNP'),
#   (',', ','),
#   ('Mr', 'NNP'),
#   ('Johnson', 'NNP'),
#   ('argued', 'VBD'),
#   ('``', '``'),
#   ('only', 'RB'),
#   ('Iran', 'NNP'),
#   ('would', 'MD'),
#   ('gain', 'VB'),
#   ("''", "''"),
#   ('from', 'IN'),
#   ('abandoning', 'VBG'),
#   ('nuclear', 'JJ'),
#   ('restrictions', 'NNS'),
#   ('.', '.'),
#   ('``', '``'),
#   ('Of', 'IN'),
#   ('all', 'PDT'),
#   ('the', 'DT'),
#   ('options', 'NNS'),
#   ('we', 'PRP'),
#   ('have', 'VBP'),
#   ('for', 'IN'),
#   ('ensuring', 'VBG'),
#   ('that', 'DT'),
#   ('Iran', 'NNP'),
#   ('never', 'RB'),
#   ('gets', 'VBZ'),
#   ('a', 'DT'),
#   ('nuclear', 'JJ'),
#   ('weapon', 'NN'),
#   (',', ','),
#   ('this', 'DT'),
#   ('pact', 'NN'),
#   ('offers', 'VBZ'),
#   ('the', 'DT'),
#   ('fewest', 'JJS'),
#   ('disadvantages', 'NNS'),
#   (',', ','),
#   ("''", "''"),
#   ('he', 'PRP'),
#   ('wrote', 'VBD'),
#   ('.', '.'),
#   ('``', '``'),
#   ('It', 'PRP'),
#   ('has', 'VBZ'),
#   ('weaknesses', 'NNS'),
#   (',', ','),
#   ('certainly', 'RB'),
#   (',', ','),
#   ('but', 'CC'),
#   ('I', 'PRP'),
#   ('am', 'VBP'),
#   ('convinced', 'VBN'),
#   ('they', 'PRP'),
#   ('can', 'MD'),
#   ('be', 'VB'),
#   ('remedied', 'VBN'),
#   ('.', '.'),
#   ('``', '``'),
#   ('Indeed', 'RB'),
#   ('at', 'IN'),
#   ('this', 'DT'),
#   ('moment', 'NN'),
#   ('Britain', 'NNP'),
#   ('is', 'VBZ'),
#   ('working', 'VBG'),
#   ('alongside', 'IN'),
#   ('the', 'DT'),
#   ('Trump', 'NNP'),
#   ('administration', 'NN'),
#   ('and', 'CC'),
#   ('our', 'PRP$'),
#   ('French', 'JJ'),
#   ('and', 'CC'),
#   ('German', 'JJ'),
#   ('allies', 'NNS'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'IN'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('.', '.'),
#   ("''", "''"),
#   ('Mr', 'NNP'),
#   ('Johnson', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('deal', 'NN'),
#   ('had', 'VBD'),
#   ('put', 'VBN'),
#   ('restrictions', 'NNS'),
#   ('on', 'IN'),
#   ('Iran', 'NNP'),
#   ("'s", 'POS'),
#   ('nuclear', 'JJ'),
#   ('programme', 'NN'),
#   ('and', 'CC'),
#   ('``', '``'),
#   ('now', 'RB'),
#   ('that', 'IN'),
#   ('these', 'DT'),
#   ('handcuffs', 'NNS'),
#   ('are', 'VBP'),
#   ('in', 'IN'),
#   ('place', 'NN'),
#   (',', ','),
#   ('I', 'PRP'),
#   ('see', 'VBP'),
#   ('no', 'DT'),
#   ('possible', 'JJ'),
#   ('advantage', 'NN'),
#   ('in', 'IN'),
#   ('casting', 'VBG'),
#   ('them', 'PRP'),
#   ('aside', 'RB'),
#   ("''", "''"),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('added', 'VBD'),
#   (':', ':'),
#   ('``', '``'),
#   ('The', 'DT'),
#   ('wisest', 'JJS'),
#   ('course', 'NN'),
#   ('would', 'MD'),
#   ('be', 'VB'),
#   ('to', 'TO'),
#   ('improve', 'VB'),
#   ('the', 'DT'),
#   ('handcuffs', 'NNS'),
#   ('rather', 'RB'),
#   ('than', 'IN'),
#   ('break', 'VB'),
#   ('them', 'PRP'),
#   ('.', '.'),
#   ("''", "''"),
#   ('While', 'IN'),
#   ('in', 'IN'),
#   ('Washington', 'NNP'),
#   (',', ','),
#   ('Mr', 'NNP'),
#   ('Johnson', 'NNP'),
#   ('will', 'MD'),
#   ('meet', 'VB'),
#   ('US', 'NNP'),
#   ('Vice-President', 'NNP'),
#   ('Mike', 'NNP'),
#   ('Pence', 'NNP'),
#   (',', ','),
#   ('National', 'NNP'),
#   ('Security', 'NNP'),
#   ('Adviser', 'NNP'),
#   ('John', 'NNP'),
#   ('Bolton', 'NNP'),
#   ('and', 'CC'),
#   ('foreign', 'JJ'),
#   ('policy', 'NN'),
#   ('leaders', 'NNS'),
#   ('in', 'IN'),
#   ('Congress', 'NNP'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('will', 'MD'),
#   ('not', 'RB'),
#   ('meet', 'VB'),
#   ('President', 'NNP'),
#   ('Trump', 'NNP'),
#   (',', ','),
#   ('but', 'CC'),
#   ('is', 'VBZ'),
#   ('expected', 'VBN'),
#   ('to', 'TO'),
#   ('appear', 'VB'),
#   ('on', 'IN'),
#   ('the', 'DT'),
#   ('Fox', 'NNP'),
#   ('&', 'CC'),
#   ('Friends', 'NNP'),
#   ('morning', 'NN'),
#   ('news', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('is', 'VBZ'),
#   ('known', 'VBN'),
#   ('to', 'TO'),
#   ('watch', 'VB'),
#   ('avidly', 'RB'),
#   ('.', '.'),
#   ('Both', 'DT'),
#   ('German', 'JJ'),
#   ('Chancellor', 'NNP'),
#   ('Angela', 'NNP'),
#   ('Merkel', 'NNP'),
#   ('and', 'CC'),
#   ('French', 'NNP'),
#   ('President', 'NNP'),
#   ('Emmanuel', 'NNP'),
#   ('Macron', 'NNP'),
#   ('have', 'VBP'),
#   ('lobbied', 'VBN'),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('directly', 'RB'),
#   ('in', 'IN'),
#   ('recent', 'JJ'),
#   ('weeks', 'NNS'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('UN', 'NNP'),
#   ('also', 'RB'),
#   ('warned', 'VBD'),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('not', 'RB'),
#   ('to', 'TO'),
#   ('walk', 'VB'),
#   ('away', 'RB'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('deal', 'NN'),
#   ('.', '.'),
#   ('But', 'CC'),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('has', 'VBZ'),
#   ('threatened', 'VBN'),
#   ('to', 'TO'),
#   ('withdraw', 'VB'),
#   ('unless', 'IN'),
#   ('the', 'DT'),
#   ('signatories', 'NNS'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('``', '``'),
#   ('fix', 'VB'),
#   ('the', 'DT'),
#   ('deal', 'NN'),
#   ("'s", 'POS'),
#   ('disastrous', 'JJ'),
#   ('flaws', 'NNS'),
#   ("''", "''"),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('president', 'NN'),
#   ('believes', 'VBZ'),
#   ('the', 'DT'),
#   ('terms', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('agreement', 'NN'),
#   ('are', 'VBP'),
#   ('too', 'RB'),
#   ('lenient', 'JJ'),
#   ('.', '.'),
#   ('Media', 'NNP'),
#   ('playback', 'NN'),
#   ('is', 'VBZ'),
#   ('unsupported', 'JJ'),
#   ('on', 'IN'),
#   ('your', 'PRP$'),
#   ('device', 'NN'),
#   ('Media', 'NNP'),
#   ('caption', 'NN'),
#   ('A', 'NNP'),
#   ('timeline', 'NN'),
#   ('of', 'IN'),
#   ('what', 'WP'),
#   ('Trump', 'NNP'),
#   ("'s", 'POS'),
#   ('said', 'VBD'),
#   ('about', 'IN'),
#   ('the', 'DT'),
#   ('Iran', 'NNP'),
#   ('deal', 'NN'),
#   ('In', 'IN'),
#   ('a', 'DT'),
#   ('call', 'NN'),
#   ('with', 'IN'),
#   ('Theresa', 'NNP'),
#   ('May', 'NNP'),
#   ('on', 'IN'),
#   ('Saturday', 'NNP'),
#   (',', ','),
#   ('Mr', 'NNP'),
#   ('Trump', 'NNP'),
#   ('``', '``'),
#   ('underscored', 'VBD'),
#   ('his', 'PRP$'),
#   ('commitment', 'NN'),
#   ('to', 'TO'),
#   ('ensure', 'VB'),
#   ('that', 'IN'),
#   ('Iran', 'NNP'),
#   ('never', 'RB'),
#   ('acquires', 'VBZ'),
#   ('a', 'DT'),
#   ('nuclear', 'JJ'),
#   ('weapon', 'NN'),
#   ("''", "''"),
#   ('.', '.'),
#   ('Iran', 'NNP'),
#   ("'s", 'POS'),
#   ('President', 'NNP'),
#   ('Hassan', 'NNP'),
#   ('Rouhani', 'NNP'),
#   ('says', 'VBZ'),
#   ('the', 'DT'),
#   ('US', 'NNP'),
#   ('will', 'MD'),
#   ('face', 'VB'),
#   ('``', '``'),
#   ('historic', 'JJ'),
#   ('regret', 'NN'),
#   ("''", "''"),
#   ('if', 'IN'),
#   ('it', 'PRP'),
#   ('pulls', 'VBZ'),
#   ('out', 'RP'),
#   ('.', '.'),
#   ('In', 'IN'),
#   ('remarks', 'NNS'),
#   ('carried', 'VBD'),
#   ('live', 'JJ'),
#   ('on', 'IN'),
#   ('state', 'NN'),
#   ('television', 'NN'),
#   (',', ','),
#   ('he', 'PRP'),
#   ('said', 'VBD'),
#   ('Iran', 'NNP'),
#   ('had', 'VBD'),
#   ('``', '``'),
#   ('a', 'DT'),
#   ('plan', 'NN'),
#   ('to', 'TO'),
#   ('counter', 'VB'),
#   ('any', 'DT'),
#   ('decision', 'NN'),
#   ('Trump', 'NN'),
#   ('may', 'MD'),
#   ('take', 'VB'),
#   ('and', 'CC'),
#   ('we', 'PRP'),
#   ('will', 'MD'),
#   ('confront', 'VB'),
#   ('it', 'PRP'),
#   ("''", "''"),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('UK-US', 'JJ'),
#   ('talks', 'NNS'),
#   ('come', 'VBP'),
#   ('after', 'IN'),
#   ('Israel', 'NNP'),
#   ('revealed', 'VBD'),
#   ('``', '``'),
#   ('secret', 'JJ'),
#   ('nuclear', 'JJ'),
#   ('files', 'NNS'),
#   ("''", "''"),
#   ('accusing', 'VBG'),
#   ('Iran', 'NNP'),
#   ('of', 'IN'),
#   ('having', 'VBG'),
#   ('run', 'VBN'),
#   ('a', 'DT'),
#   ('secret', 'JJ'),
#   ('nuclear', 'JJ'),
#   ('weapons', 'NNS'),
#   ('programme', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('was', 'VBD'),
#   ('reportedly', 'RB'),
#   ('mothballed', 'VBN'),
#   ('15', 'CD'),
#   ('years', 'NNS'),
#   ('ago', 'RB'),
#   ('.', '.'),
#   ('US', 'NNP'),
#   ('Secretary', 'NNP'),
#   ('of', 'IN'),
#   ('State', 'NNP'),
#   ('Mike', 'NNP'),
#   ('Pompeo', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('documents', 'NNS'),
#   ('were', 'VBD'),
#   ('authentic', 'JJ'),
#   ('and', 'CC'),
#   ('show', 'VB'),
#   ('the', 'DT'),
#   ('2015', 'CD'),
#   ('Iran', 'NNP'),
#   ('nuclear', 'JJ'),
#   ('deal', 'NN'),
#   ('was', 'VBD'),
#   ('``', '``'),
#   ('built', 'VBN'),
#   ('on', 'IN'),
#   ('lies', 'NNS'),
#   ("''", "''"),
#   ('.', '.'),
#   ('Iran', 'NNP'),
#   (',', ','),
#   ('in', 'IN'),
#   ('turn', 'NN'),
#   (',', ','),
#   ('accused', 'VBN'),
#   ('Mr', 'NNP'),
#   ('Netanyahu', 'NNP'),
#   ('of', 'IN'),
#   ('lying', 'VBG'),
#   ('.', '.'),
#   ('Foreign', 'NNP'),
#   ('Minister', 'NNP'),
#   ('Javad', 'NNP'),
#   ('Zarif', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('documents', 'NNS'),
#   ('produced', 'VBN'),
#   ('by', 'IN'),
#   ('Israel', 'NNP'),
#   ('were', 'VBD'),
#   ('a', 'DT'),
#   ('rehash', 'NN'),
#   ('of', 'IN'),
#   ('old', 'JJ'),
#   ('allegations', 'NNS'),
#   ('already', 'RB'),
#   ('dealt', 'VBP'),
#   ('with', 'IN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('International', 'NNP'),
#   ('Atomic', 'NNP'),
#   ('Energy', 'NNP'),
#   ('Agency', 'NNP'),
#   ('(', '('),
#   ('IAEA', 'NNP'),
#   (')', ')'),
#   (',', ','),
#   ('the', 'DT'),
#   ('UN', 'NNP'),
#   ("'s", 'POS'),
#   ('nuclear', 'JJ'),
#   ('watchdog', 'NN'),
#   ('.', '.'),
#   ('Media', 'NNP'),
#   ('playback', 'NN'),
#   ('is', 'VBZ'),
#   ('unsupported', 'JJ'),
#   ('on', 'IN'),
#   ('your', 'PRP$'),
#   ('device', 'NN'),
#   ('Media', 'NNP'),
#   ('caption', 'NN'),
#   ('What', 'WP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('Iran', 'NNP'),
#   ('nuclear', 'JJ'),
#   ('deal', 'NN'),
#   ('?', '.'),
#   ('The', 'DT'),
#   ('UK', 'NNP'),
#   ("'s", 'POS'),
#   ('ambassador', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('US', 'NNP'),
#   ('Sir', 'NNP'),
#   ('Kim', 'NNP'),
#   ('Darroch', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('Iran', 'NNP'),
#   ('agreement', 'NN'),
#   ('was', 'VBD'),
#   ('``', '``'),
#   ('a', 'DT'),
#   ('good', 'JJ'),
#   ('deal', 'NN'),
#   ("''", "''"),
#   ('but', 'CC'),
#   ('efforts', 'NNS'),
#   ('were', 'VBD'),
#   ('ongoing', 'VBG'),
#   ('to', 'TO'),
#   ('``', '``'),
#   ('find', 'VB'),
#   ('some', 'DT'),
#   ('language', 'NN'),
#   (',', ','),
#   ('produce', 'VBP'),
#   ('some', 'DT'),
#   ('action', 'NN'),
#   ('that', 'WDT'),
#   ('meets', 'VBZ'),
#   ('the', 'DT'),
#   ('president', 'NN'),
#   ("'s", 'POS'),
#   ('concerns', 'NNS'),
#   ("''", "''"),
#   ('.', '.'),
#   ('``', '``'),
#   ('We', 'PRP'),
#   ('think', 'VBP'),
#   ('we', 'PRP'),
#   ("'re", 'VBP'),
#   ('making', 'VBG'),
#   ('progress', 'NN'),
#   ('.', '.'),
#   ('We', 'PRP'),
#   ('have', 'VBP'),
#   ("n't", 'RB'),
#   ('got', 'VBN'),
#   ('there', 'RB'),
#   ('yet', 'RB'),
#   ('.', '.'),
#   ('We', 'PRP'),
#   ('have', 'VBP'),
#   ('a', 'DT'),
#   ('few', 'JJ'),
#   ('days', 'NNS'),
#   ('left', 'VBD'),
#   ('to', 'TO'),
#   ('see', 'VB'),
#   ('if', 'IN'),
#   ('we', 'PRP'),
#   ('can', 'MD'),
#   ('find', 'VB'),
#   ('a', 'DT'),
#   ('way', 'NN'),
#   ('through', 'IN'),
#   (',', ','),
#   ("''", "''"),
#   ('he', 'PRP'),
#   ('said', 'VBD'),
#   ('.', '.'),
#   ('He', 'PRP'),
#   ('added', 'VBD'),
#   ('that', 'IN'),
#   ('Britain', 'NNP'),
#   ('and', 'CC'),
#   ('its', 'PRP$'),
#   ('European', 'JJ'),
#   ('partners', 'NNS'),
#   ('were', 'VBD'),
#   ('also', 'RB'),
#   ('looking', 'VBG'),
#   ('at', 'IN'),
#   ('how', 'WRB'),
#   ('a', 'DT'),
#   ('deal', 'NN'),
#   ('would', 'MD'),
#   ('work', 'VB'),
#   ('even', 'RB'),
#   ('without', 'IN'),
#   ('the', 'DT'),
#   ('US', 'NNP'),
#   ('.', '.')],
#  [('Image', 'NN'),
#   ('copyright', 'VBD'),
#   ('Getty', 'NNP'),
#   ('Images', 'NNP'),
#   ('Glasgow', 'NNP'),
#   ('Queen', 'NNP'),
#   ('Street', 'NNP'),
#   ('has', 'VBZ'),
#   ('been', 'VBN'),
#   ('named', 'VBN'),
#   ('Britain', 'NNP'),
#   ("'s", 'POS'),
#   ('most', 'JJS'),
#   ('unpopular', 'JJ'),
#   ('railway', 'NN'),
#   ('station', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('survey', 'NN'),
#   ('of', 'IN'),
#   ('passengers', 'NNS'),
#   ('.', '.'),
#   ('Independent', 'NNP'),
#   ('watchdog', 'JJ'),
#   ('Transport', 'NNP'),
#   ('Focus', 'NNP'),
#   ('took', 'VBD'),
#   ('the', 'DT'),
#   ('views', 'NNS'),
#   ('of', 'IN'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('28,000', 'CD'),
#   ('people', 'NNS'),
#   ('at', 'IN'),
#   ('56', 'CD'),
#   ('stations', 'NNS'),
#   ('for', 'IN'),
#   ('its', 'PRP$'),
#   ('ranking', 'NN'),
#   ('.', '.'),
#   ('Only', 'RB'),
#   ('58', 'CD'),
#   ('%', 'NN'),
#   ('of', 'IN'),
#   ('travellers', 'NNS'),
#   ('were', 'VBD'),
#   ('``', '``'),
#   ('satisfied', 'JJ'),
#   ("''", "''"),
#   ('with', 'IN'),
#   ('Queen', 'NNP'),
#   ('Street', 'NNP'),
#   (',', ','),
#   ('Scotland', 'NNP'),
#   ("'s", 'POS'),
#   ('third', 'JJ'),
#   ('busiest', 'JJS'),
#   ('station', 'NN'),
#   ('.', '.'),
#   ('Glasgow', 'NNP'),
#   ('Central', 'NNP'),
#   ('nearby', 'RB'),
#   ('made', 'VBD'),
#   ('the', 'DT'),
#   ('top', 'JJ'),
#   ('10', 'CD'),
#   ('with', 'IN'),
#   ('a', 'DT'),
#   ('91', 'CD'),
#   ('%', 'NN'),
#   ('approval', 'NN'),
#   ('.', '.'),
#   ('London', 'NNP'),
#   ('King', 'NNP'),
#   ("'s", 'POS'),
#   ('Cross', 'NNP'),
#   ('achieved', 'VBD'),
#   ('a', 'DT'),
#   ('96', 'CD'),
#   ('%', 'NN'),
#   ('score', 'NN'),
#   ('and', 'CC'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('most', 'RBS'),
#   ('popular', 'JJ'),
#   ('station', 'NN'),
#   (',', ','),
#   ('just', 'RB'),
#   ('above', 'IN'),
#   ('neighbouring', 'VBG'),
#   ('St', 'NNP'),
#   ('Pancras', 'NNP'),
#   ('.', '.'),
#   ('Transport', 'NNP'),
#   ('Focus', 'NNP'),
#   ('said', 'VBD'),
#   ('the', 'DT'),
#   ('top', 'JJ'),
#   ('priorities', 'NNS'),
#   ('for', 'IN'),
#   ('passengers', 'NNS'),
#   ('were', 'VBD'),
#   ('arrival', 'JJ'),
#   ('time', 'NN'),
#   ('information', 'NN'),
#   (',', ','),
#   ('waiting', 'VBG'),
#   ('rooms', 'NNS'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('overall', 'JJ'),
#   ('look', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('station', 'NN'),
#   ('when', 'WRB'),
#   ('it', 'PRP'),
#   ('carried', 'VBD'),
#   ('out', 'RP'),
#   ('the', 'DT'),
#   ('survey', 'NN'),
#   ('between', 'IN'),
#   ('September', 'NNP'),
#   ('and', 'CC'),
#   ('November', 'NNP'),
#   ('last', 'JJ'),
#   ('year', 'NN'),
#   ('.', '.'),
#   ('Glasgow', 'NNP'),
#   ('Queen', 'NNP'),
#   ('Street', 'NNP'),
#   ('is', 'VBZ'),
#   ('currently', 'RB'),
#   ('undergoing', 'VBG'),
#   ('a', 'DT'),
#   ('£100m', 'JJ'),
#   ('redevelopment', 'NN'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('is', 'VBZ'),
#   ('set', 'VBN'),
#   ('to', 'TO'),
#   ('be', 'VB'),
#   ('completed', 'VBN'),
#   ('by', 'IN'),
#   ('2019', 'CD'),
#   ('.', '.'),
#   ('Britain', 'NNP'),
#   ("'s", 'POS'),
#   ('most', 'JJS'),
#   ('unpopular', 'JJ'),
#   ('stations', 'NNS'),
#   ('The', 'DT'),
#   ('stations', 'NNS'),
#   ('passengers', 'NNS'),
#   ('were', 'VBD'),
#   ('least', 'JJS'),
#   ('happy', 'JJ'),
#   ('with', 'IN'),
#   ('between', 'IN'),
#   ('September', 'NNP'),
#   ('and', 'CC'),
#   ('November', 'NNP'),
#   ('2017', 'CD'),
#   ('-', ':'),
#   ('and', 'CC'),
#   ('their', 'PRP$'),
#   ('satisfaction', 'NN'),
#   ('rating', 'NN'),
#   (':', ':'),
#   ('Glasgow', 'NNP'),
#   ('Queen', 'NNP'),
#   ('Street', 'NNP'),
#   ('-', ':'),
#   ('58', 'CD'),
#   ('%', 'NN'),
#   ('Gatwick', 'NNP'),
#   ('Airport', 'NNP'),
#   ('-', ':'),
#   ('66', 'CD'),
#   ('%', 'NN'),
#   ('Oxford', 'NNP'),
#   ('-', ':'),
#   ('67', 'CD'),
#   ('%', 'NN'),
#   ('Clapham', 'NNP'),
#   ('Junction', 'NNP'),
#   ('-', ':'),
#   ('69', 'CD'),
#   ('%', 'NN'),
#   ('Barking', 'NNP'),
#   ('-', ':'),
#   ('70', 'CD'),
#   ('%', 'NN'),
#   ('Wimbledon', 'NNP'),
#   ('-', ':'),
#   ('71', 'CD'),
#   ('%', 'NN'),
#   ('London', 'NNP'),
#   ('Victoria', 'NNP'),
#   ('-', ':'),
#   ('72', 'CD'),
#   ('%', 'NN'),
#   ('Highbury', 'NNP'),
#   ('and', 'CC'),
#   ('Islington', 'NNP'),
#   ('-', ':'),
#   ('72', 'CD'),
#   ('%', 'NN'),
#   ('Hull', 'NNP'),
#   ('-', ':'),
#   ('73', 'CD'),
#   ('%', 'NN'),
#   ('Cardiff', 'NNP'),
#   ('Central', 'NNP'),
#   ('-', ':'),
#   ('75', 'CD'),
#   ('%', 'NN'),
#   ('The', 'DT'),
#   ('second', 'JJ'),
#   ('worst', 'JJ'),
#   ('satisfaction', 'NN'),
#   ('ranking', 'NN'),
#   ('(', '('),
#   ('66', 'CD'),
#   ('%', 'NN'),
#   (')', ')'),
#   ('was', 'VBD'),
#   ('given', 'VBN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('station', 'NN'),
#   ('at', 'IN'),
#   ('Gatwick', 'NNP'),
#   ('Airport', 'NNP'),
#   ('.', '.'),
#   ('One', 'CD'),
#   ('passengers', 'NNS'),
#   ('described', 'VBD'),
#   ('it', 'PRP'),
#   ('as', 'IN'),
#   ('``', '``'),
#   ('small', 'JJ'),
#   ('and', 'CC'),
#   ('cramped', 'JJ'),
#   ("''", "''"),
#   ('and', 'CC'),
#   ('spoke', 'VBD'),
#   ('of', 'IN'),
#   ('overcrowding', 'VBG'),
#   ('on', 'IN'),
#   ('platforms', 'NNS'),
#   ('and', 'CC'),
#   ('long', 'JJ'),
#   ('ticket', 'NN'),
#   ('queues', 'NNS'),
#   ('.', '.'),
#   ('Another', 'DT'),
#   ('said', 'VBD'),
#   ('it', 'PRP'),
#   ('was', 'VBD'),
#   ('an', 'DT'),
#   ('``', '``'),
#   ('appalling', 'JJ'),
#   ('welcome', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('UK', 'NNP'),
#   ("''", "''"),
#   ('.', '.'),
#   ('Image', 'NNP'),
#   ('copyright', 'VBD'),
#   ('Getty', 'NNP'),
#   ('Images', 'NNP'),
#   ('Image', 'NNP'),
#   ('caption', 'NN'),
#   ('The', 'DT'),
#   ('recently', 'RB'),
#   ('refurbished', 'VBN'),
#   ('London', 'NNP'),
#   ('King', 'NNP'),
#   ("'s", 'POS'),
#   ('Cross', 'NNP'),
#   ('was', 'VBD'),
#   ('the', 'DT'),
#   ('top-rated', 'JJ'),
#   ('station', 'NN'),
#   ('The', 'DT'),
#   ('four', 'CD'),
#   ('stations', 'NNS'),
#   (',', ','),
#   ('which', 'WDT'),
#   ('ranked', 'VBD'),
#   ('the', 'DT'),
# ...
#   ('be', 'VB'),
#   ('fine-tuned', 'JJ'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('architect', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   ('specifications', 'NNS'),
#   ('and', 'CC'),
#   ('are', 'VBP'),
#   ('lighter—weighing', 'VBG'),
#   ('a', 'DT'),
#   ('fifth', 'NN'),
#   ('of', 'IN'),
#   ('concrete', 'NN'),
#   ('.', '.'),
#   ('Accra', 'NNP'),
#   ('Waste', 'NNP'),
#   ('Treatment', 'NNP'),
#   ('Ghana', 'NNP'),
#   ('’', 'NNP'),
#   ('s', 'VBD'),
#   ('first', 'JJ'),
#   ('fecal', 'JJ'),
#   ('treatment', 'NN'),
#   ('plant', 'NN'),
#   ('is', 'VBZ'),
#   ('cleaning', 'VBG'),
#   ('up', 'RP'),
#   ('Accra', 'NNP'),
#   ('and', 'CC'),
#   ('providing', 'VBG'),
#   ('sustainable', 'JJ'),
#   ('energy', 'NN'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('country', 'NN'),
#   ('’', 'NNP'),
#   ('s', 'VBD'),
#   ('first', 'JJ'),
#   ('modern', 'JJ'),
#   ('treatment', 'NN'),
#   ('plant', 'NN'),
#   ('became', 'VBD'),
#   ('operational', 'JJ'),
#   ('in', 'IN'),
#   ('2017', 'CD'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('resulting', 'VBG'),
#   ('biogas', 'NN'),
#   ('that', 'WDT'),
#   ('’', 'VBZ'),
#   ('s', 'RB'),
#   ('captured', 'VBN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('decomposing', 'NN'),
#   ('sewage', 'NN'),
#   ('is', 'VBZ'),
#   ('being', 'VBG'),
#   ('used', 'VBN'),
#   ('to', 'TO'),
#   ('power', 'NN'),
#   ('the', 'DT'),
#   ('plant', 'NN'),
#   ('.', '.'),
#   ('Further', 'NNP'),
#   (',', ','),
#   ('the', 'DT'),
#   ('residual', 'JJ'),
#   ('sludge', 'NN'),
#   ('from', 'IN'),
#   ('the', 'DT'),
#   ('plant', 'NN'),
#   ('is', 'VBZ'),
#   ('also', 'RB'),
#   ('turned', 'VBN'),
#   ('into', 'IN'),
#   ('charcoal', 'NN'),
#   ('and', 'CC'),
#   ('compost', 'NN'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('creators', 'NNS'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('charcoal', 'NNS'),
#   ('say', 'VBP'),
#   ('that', 'IN'),
#   ('the', 'DT'),
#   ('feces-based', 'JJ'),
#   ('burning', 'NN'),
#   ('material', 'NN'),
#   ('works', 'VBZ'),
#   ('better', 'RBR'),
#   ('than', 'IN'),
#   ('wood', 'NN'),
#   ('and', 'CC'),
#   ('saves', 'NNS'),
#   ('trees', 'NNS'),
#   ('from', 'IN'),
#   ('being', 'VBG'),
#   ('felled', 'VBN'),
#   ('.', '.'),
#   ('Rotterdam', 'NNP'),
#   ('Flood', 'NNP'),
#   ('Protection', 'NNP'),
#   ('With', 'IN'),
#   ('much', 'JJ'),
#   ('of', 'IN'),
#   ('their', 'PRP$'),
#   ('country', 'NN'),
#   ('below', 'IN'),
#   ('sea', 'NN'),
#   ('level', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('Dutch', 'NNPS'),
#   ('have', 'VBP'),
#   ('always', 'RB'),
#   ('had', 'VBN'),
#   ('to', 'TO'),
#   ('innovate', 'VB'),
#   ('to', 'TO'),
#   ('keep', 'VB'),
#   ('themselves', 'PRP'),
#   ('dry', 'JJ'),
#   ('.', '.'),
#   ('From', 'IN'),
#   ('man-made', 'JJ'),
#   ('lakes', 'NNS'),
#   ('to', 'TO'),
#   ('parks', 'VB'),
#   ('that', 'DT'),
#   ('double', 'JJ'),
#   ('as', 'IN'),
#   ('reservoirs', 'NNS'),
#   ('for', 'IN'),
#   ('excess', 'JJ'),
#   ('water', 'NN'),
#   (',', ','),
#   ('part', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('solution', 'NN'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('seems', 'VBZ'),
#   (',', ','),
#   ('lies', 'VBZ'),
#   ('in', 'IN'),
#   ('living', 'VBG'),
#   ('with', 'IN'),
#   ('the', 'DT'),
#   ('water', 'NN'),
#   (',', ','),
#   ('rather', 'RB'),
#   ('than', 'IN'),
#   ('resisting', 'VBG'),
#   ('it', 'PRP'),
#   ('with', 'IN'),
#   ('large', 'JJ'),
#   (',', ','),
#   ('unsightly', 'RB'),
#   ('levees', 'VBZ'),
#   ('.', '.'),
#   ('The', 'DT'),
#   ('first', 'JJ'),
#   ('line', 'NN'),
#   ('of', 'IN'),
#   ('defense', 'NN'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('city', 'NN'),
#   ('of', 'IN'),
#   ('Rotterdam', 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('Maeslantkering', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('sea', 'NN'),
#   ('gate', 'NN'),
#   ('that', 'WDT'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('size', 'NN'),
#   ('of', 'IN'),
#   ('two', 'CD'),
#   ('Eiffel', 'NNP'),
#   ('Towers', 'NNPS'),
#   ('.', '.'),
#   ('Opened', 'VBN'),
#   ('in', 'IN'),
#   ('1997', 'CD'),
#   (',', ','),
#   ('the', 'DT'),
#   ('gate', 'NN'),
#   ('protects', 'VBZ'),
#   ('the', 'DT'),
#   ('Rotterdam', 'NNP'),
#   ('’', 'NNP'),
#   ('s', 'NN'),
#   ('port', 'NN'),
#   (',', ','),
#   ('with', 'IN'),
#   ('plans', 'NNS'),
#   ('to', 'TO'),
#   ('add', 'VB'),
#   ('another', 'DT'),
#   ('two', 'CD'),
#   ('feet', 'NNS'),
#   ('to', 'TO'),
#   ('its', 'PRP$'),
#   ('height', 'JJ'),
#   ('underway', 'NN'),
#   ('.', '.'),
#   ('But', 'CC'),
#   ('as', 'IN'),
#   ('sea', 'NN'),
#   ('levels', 'NNS'),
#   ('rise', 'NN'),
#   (',', ','),
#   ('the', 'DT'),
#   ('stakes', 'NNS'),
#   ('are', 'VBP'),
#   ('getting', 'VBG'),
#   ('even', 'RB'),
#   ('higher', 'JJR'),
#   ('.', '.'),
#   ('And', 'CC'),
#   ('for', 'IN'),
#   ('some', 'DT'),
#   ('entrepreneurs', 'NNS'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('Netherlands', 'NNP'),
#   (',', ','),
#   ('it', 'PRP'),
#   ('spells', 'VBZ'),
#   ('opportunity', 'NN'),
#   ('.', '.'),
#   ('CNN', 'NNP'),
#   ('travels', 'VBZ'),
#   ('to', 'TO'),
#   ('Rotterdam', 'VB'),
#   ('to', 'TO'),
#   ('explore', 'VB'),
#   ('some', 'DT'),
#   ('of', 'IN'),
#   ('these', 'DT'),
#   ('recent', 'JJ'),
#   ('innovations', 'NNS'),
#   (',', ','),
#   ('including', 'VBG'),
#   ('the', 'DT'),
#   ('Delta', 'NNP'),
#   ('Flume', 'NNP'),
#   (',', ','),
#   ('a', 'DT'),
#   ('wave', 'NN'),
#   ('simulator', 'NN'),
#   ('that', 'WDT'),
#   ('can', 'MD'),
#   ('help', 'VB'),
#   ('researchers', 'NNS'),
#   ('understand', 'VB'),
#   ('what', 'WP'),
#   ('it', 'PRP'),
#   ('takes', 'VBZ'),
#   ('to', 'TO'),
#   ('withstand', 'VB'),
#   ('storm', 'NN'),
#   ('surges', 'NNS'),
#   ('and', 'CC'),
#   ('tides', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('Sand', 'NNP'),
#   ('Motor', 'NNP'),
#   (',', ','),
#   ('an', 'DT'),
#   ('experiment', 'NN'),
#   ('in', 'IN'),
#   ('coastal', 'JJ'),
#   ('management', 'NN'),
#   ('.', '.'),
#   ('‘', 'VB'),
#   ('Innovative', 'JJ'),
#   ('Cities', 'NNPS'),
#   ('’', 'NNP'),
#   ('microsite', 'NN'),
#   (':', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//money.cnn.com/technology/innovative-cities/', 'JJ'),
#   ('‘', 'NNP'),
#   ('Innovative', 'NNP'),
#   ('Cities', 'NNP'),
#   ('’', 'NNP'),
#   ('trailer', 'NN'),
#   (':', ':'),
#   ('http', 'NN'),
#   (':', ':'),
#   ('//cnn.it/2FIDXr6', 'NN'),
#   ('Airtimes', 'NNP'),
#   ('for', 'IN'),
#   ('30-minute', 'JJ'),
#   ('special', 'JJ'),
#   (':', ':'),
#   ('Saturday', 'NNP'),
#   (',', ','),
#   ('17th', 'CD'),
#   ('March', 'NNP'),
#   ('at', 'IN'),
#   ('2030', 'CD'),
#   ('and', 'CC'),
#   ('2330', 'CD'),
#   ('HKT', 'NNP'),
#   ('Sunday', 'NNP'),
#   (',', ','),
#   ('18th', 'CD'),
#   ('March', 'NNP'),
#   ('at', 'IN'),
#   ('0330', 'CD'),
#   (',', ','),
#   ('0830', 'CD'),
#   ('and', 'CC'),
#   ('1130', 'CD'),
#   ('HKT', 'NNP'),
#   ('Tuesday', 'NNP'),
#   (',', ','),
#   ('20th', 'CD'),
#   ('March', 'NNP'),
#   ('at', 'IN'),
#   ('1730', 'CD'),
#   ('HKT', 'NNP'),
#   ('Wednesday', 'NNP'),
#   (',', ','),
#   ('21st', 'CD'),
#   ('March', 'NNP'),
#   ('at', 'IN'),
#   ('0030', 'CD'),
#   ('and', 'CC'),
#   ('1630', 'CD'),
#   ('HKT', 'NNP'),
#   ('Thursday', 'NNP'),
#   (',', ','),
#   ('29th', 'CD'),
#   ('March', 'NNP'),
#   ('at', 'IN'),
#   ('1630', 'CD'),
#   ('HKT', 'NNP')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')],
#  [('By', 'IN'),
#   ('continuing', 'VBG'),
#   ('to', 'TO'),
#   ('browse', 'VB'),
#   ('our', 'PRP$'),
#   ('site', 'NN'),
#   ('you', 'PRP'),
#   ('agree', 'VBP'),
#   ('to', 'TO'),
#   ('our', 'PRP$'),
#   ('use', 'NN'),
#   ('of', 'IN'),
#   ('cookies', 'NNS'),
#   (',', ','),
#   ('revised', 'VBN'),
#   ('Privacy', 'NN'),
#   ('Policy', 'NNP'),
#   ('and', 'CC'),
#   ('Terms', 'NNS'),
#   ('of', 'IN'),
#   ('Use', 'NNP'),
#   ('.', '.'),
#   ('More', 'JJR'),
#   ('information', 'NN'),
#   ('about', 'IN'),
#   ('cookies', 'NNS')]]

# %%
nert.tag(tokens= token[1],self=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-208-d963b54bea77> in <module>()
#       1
# ----> 2 nert.tag(tokens= token[1])
#
# TypeError: tag() missing 1 required positional argument: 'self'
